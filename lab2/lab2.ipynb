# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Fuctional

plt.plot(x, y)        #build plot
plt.xlabel('X lable') #add name of x axis
plt.ylabel('Y lable') #add name of y axis
plt.title('title')    #add title
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1, 2, 1) #Create first plot: 1row, 2 colums, 1st plot
plt.plot(x, y, 'r')

plt.subplot(1, 2, 2) #Create second plot: 1row, 2 colums, 2t plot
plt.plot(y, x, 'g')

# %%
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])

axes.plot(x, y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1])
axes2 = fig.add_axes([0.1, 0.5, 0.4, 0.3])

axes1.plot(x, y, 'y')
axes1.set_xlabel('X label')
axes1.set_ylabel('Y label')
axes1.set_title('Title')

axes2.plot(y, x, 'm')
axes2.set_xlabel('X label')
axes2.set_ylabel('Y label')
axes2.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots()

axes.plot(x, y, 'm')
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)
axes[0].plot(x, y, 'pink')
axes[1].plot(y, x, 'g')

# %%
fig, axes = plt.subplots(nrows = 4, ncols = 4)
plt.tight_layout()

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, x**2, label = "x^2")
ax.plot(x, x**3, label = "x^3")
ax.legend()

# %%
fig = plt.figure(figsize = (8,4), dpi = 100)

# %%
fig.savefig("fig.pdf")

# %%
plt.scatter(x, y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([ 6.,  9.,  9., 15., 13., 11.,  9., 10.,  8., 10.]),
#  array([ 12. , 109.3, 206.6, 303.9, 401.2, 498.5, 595.8, 693.1, 790.4,
#         887.7, 985. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

plt.boxplot(data, vert=True, patch_artist=True);
